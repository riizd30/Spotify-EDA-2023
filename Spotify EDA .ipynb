# %% [markdown]
# # Spotify Exploratory Data Analysis

# %% [markdown]
# Objective Purpose :
# 1. Analyzing the dataset about "Most Streamed Song in 2023 on Spotify Platform"
# 2. How the most popular song on Spotify Platformn 2020 until 2023
# 3. The preference of music features from people that make a song to listen and be popular song
# 4. The Relationship between chart and playlist on Spotify Platform

# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_csv('spotify-2023.csv', encoding='iso-8859-1')

# %%
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
data.shape
# Out:
# (953, 24)

# %% [markdown]
# # Data Understanding

# %%
data.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
data.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# # Data Cleaning

# %%
missing_values = data.isna().sum()
missing_values = missing_values[missing_values > 0]
missing_values
# Out:
# in_shazam_charts    50
# key                 95
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# # Filling Null of Data

# %%
data['key'] = data['key'].fillna('Unknown')
data['in_shazam_charts'] = data['in_shazam_charts'].fillna('0')

# %%
data.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %% [markdown]
# # Date of Time

# %%
data['released_date'] = data['released_year'].astype(str) + '-' + data['released_month'].astype(str) + '-' + data['released_day'].astype(str)

# %%
data['released_date'] = pd.to_datetime(data['released_date'])

# %%
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# ...

# %%
data.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# released_date           0
# dtype: int64

# %% [markdown]
# I add new column combination from released_year, released_month, released_day with the new column to be released_date

# %% [markdown]
# # Drop Columns of Data Time

# %%
df= data.drop(["released_month","released_day"], axis=1)

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  in_spotify_playlists  in_spotify_charts    streams  \
# 0           2023                   553                147  141381703
# 1           2023                  1474                 48  133716286
# 2           2023                  1397                113  140003974
# 3           2019                  7858                100  800840817
# 4           2023                  3133                 50  303236322
#
#    in_apple_playlists  in_apple_charts in_deezer_playlists  ...  key   mode  \
# ...

# %% [markdown]
# I alse drop the column of released_month and released_month from dataset

# %% [markdown]
# # Change The Types of Data

# %%
df['streams'] = df['streams'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df['streams'] = df['streams'].astype('int64')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df[df['streams']=='BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3']
# Out:
#                               track_name     artist(s)_name  artist_count  \
# 574  Love Grows (Where My Rosemary Goes)  Edison Lighthouse             1
#
#      released_year  in_spotify_playlists  in_spotify_charts  \
# 574           1970                  2877                  0
#
#                                                streams  in_apple_playlists  \
# 574  BPM110KeyAModeMajorDanceability53Valence75Ener...                  16
#
#      in_apple_charts in_deezer_playlists  ...  key   mode  danceability_%  \
# 574                0                  54  ...    A  Major              53
#
#     valence_% energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# 574        75       69               7                   0          17
#
#      speechiness_%  released_date
# 574              3     1970-01-01
#
# [1 rows x 23 columns]

# %% [markdown]
# there is a error, coused by an unexpected string. So i check and will do change.

# %%
df = df[df['streams']!='BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3']

# %%
df['streams'] = df['streams'].astype('int64')

# %%
df['in_shazam_charts'] =  df['in_shazam_charts'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df['in_shazam_charts'] =  df['in_shazam_charts'].astype('int64')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %% [markdown]
# there is a error too, so i check and will replace the error one with no punctuation.

# %%
df['in_shazam_charts'] = df['in_shazam_charts'].str.replace(',', '')
df['in_deezer_playlists'] = df['in_deezer_playlists'].str.replace(',', '')

# %%
df['in_shazam_charts'] =  df['in_shazam_charts'].astype('int64')
df['in_deezer_playlists'] =  df['in_deezer_playlists'].astype('int64')

# %% [markdown]
# i changed a few colomn of data type to "int64"

# %%
df.dtypes
# Out:
# track_name                      object
# artist(s)_name                  object
# artist_count                     int64
# released_year                    int64
# in_spotify_playlists             int64
# in_spotify_charts                int64
# streams                          int64
# in_apple_playlists               int64
# in_apple_charts                  int64
# in_deezer_playlists              int64
# in_deezer_charts                 int64
# in_shazam_charts                 int64
# bpm                              int64
# key                             object
# mode                            object
# danceability_%                   int64
# valence_%                        int64
# energy_%                         int64
# acousticness_%                   int64
# instrumentalness_%               int64
# liveness_%                       int64
# speechiness_%                    int64
# released_date           datetime64[ns]
# dtype: object

# %% [markdown]
# # Check The Outliers

# %%
df.plot(layout = (5,10), sharex = False, sharey = False, subplots = True, figsize = (25, 15), color ='Red', kind = 'box' )
plt.show()

# %% [markdown]
# Because the data has many outliers, go and let it be. In case this data set is a music chart. And then there are possibilities that a song is placed in the other positions because of the charts.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
#  ### Use Function of compute_distribution

# %%
def compute_distribution(df1, column_name):
    distribution = df1[column_name].value_counts(normalize=True) * 100
    sorted_distribution = distribution.sort_values(ascending=False).reset_index()
    sorted_distribution.columns = [column_name.capitalize(), 'Percentage']
    return sorted_distribution

# %% [markdown]
# ### Use Function of plot_pie_chart

# %%
def plot_pie_chart(df, title, subplot_position):
    plt.subplot(2, 2, subplot_position)
    plt.pie(df['Percentage'], labels=df[df.columns[0]], autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel", len(data)))
    plt.title(title)

# %% [markdown]
# ## Average % of Features Music and Mode Distribution

# %%
def visualize_data(df1):

    # List of parameters to compute mean values
    para_list = ['danceability_%', 'energy_%', 'valence_%', 'acousticness_%', 'liveness_%', 'speechiness_%', 'instrumentalness_%']

    # Compute mean values using a dictionary comprehension
    paras = {para.split('_')[0].capitalize(): df[para].mean() for para in para_list}

    # Plotting
    plt.figure(figsize=(15, 10))

    # Bar chart for parameters
    plt.subplot(2, 2, 1)
    sns.barplot(x=list(paras.keys()), y=list(paras.values()), palette="pastel")
    plt.title('Average % of Music Features')
    plt.ylabel('%')
    plt.xticks(rotation=45)

    # Pie charts
    plot_pie_chart(compute_distribution(df1, 'mode'), 'Mode Distribution', 2)
    
    plt.tight_layout()
    plt.show()


# Visualize the data
visualize_data(df)

# %% [markdown]
# The analysis of Spotify 2023 to know about "Average % of Music Features" provides valuable insights into musical characteristic from music features that makes a song popular.
#
# 1. **Music Features** :
#    * Danceability: Have a score of 67% on average total. These features have a nice score because, in this era, the song has a dance vibe and is suitable for dancing. Also, people in this era always take videos on social media such as TikTok and Instagram with the song.
#    *   Energy: This feature has a good score of 64%. Just because the song has a good sound, vibrant and good tempo in the song.
#    *   Valance: The average of valence has a score of 51%. It seems to have a balanced mix of valence into positive and negative moods
#    *   acousticness: This feature just has a score of 27% of the average percentage. In this era, the components of songs always preferred BOP, electronic, and synthesized vibes and sounds.
#    *   liveness: This feature scores average of 18%. Because most of the song always recorded a studio rather than in live performances
#    *   speechiness: For this feature just has a score of 10%
#    *   instrumentalness: The song mostly just has a lil space for instrumental and has a score of average at 2%.
# 2. **Mode Distributions**: \
#    The score of Major Mode is 57.7% and for Minor Mode is 42.3%. It seems to have similiarity with the valance of music feature that the Major mode is often associated with happier sounds, and Minor mode is associated to sadder moods.

# %% [markdown]
# ## Most Streamed Song in 2023

# %%
top_song = df[['artist(s)_name','track_name','streams','in_spotify_charts','in_apple_charts','in_deezer_charts','in_shazam_charts','released_year','released_date']].sort_values(by='streams', ascending=False)
top_song
# Out:
#                                         artist(s)_name  \
# 55                                          The Weeknd
# 179                                         Ed Sheeran
# 86                                       Lewis Capaldi
# 620                                        Tones and I
# 41                               Post Malone, Swae Lee
# ..                                                 ...
# 68                                         Post Malone
# 142                                Mc Pedrinho, DJ 900
# 144                       Sog, Ryan Castro, Peso Pluma
# 393  Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...
# 123                         Carin Leon, Grupo Frontera
#
#                                         track_name     streams  \
# 55                                 Blinding Lights  3703895074
# 179                                   Shape of You  3562543890
# 86                               Someone You Loved  2887241814
# ...

# %% [markdown]
# **This is top 10 of most streamed start from  1987 until 2023**

# %%
top_song_2023 = df.loc[(df['released_year']>=2020)]

# %% [markdown]
# so, i filter the dataset for years that start from 2020 until 2023 to make a conclusion

# %% [markdown]
# ## The Most Popular Song Streamed on Spotify Platform Between 2020 untill 2023?

# %%
top_10_spotify = top_song_2023[['artist(s)_name','track_name','released_date','streams','in_spotify_playlists','in_spotify_charts']].sort_values(by='streams', ascending=False).head(10)

# %%
top_10_spotify.head(10)
# Out:
#                    artist(s)_name                         track_name  \
# 84   Justin Bieber, The Kid Laroi          STAY (with Justin Bieber)
# 71                  Glass Animals                         Heat Waves
# 14                   Harry Styles                          As It Was
# 513                Olivia Rodrigo                           good 4 u
# 535                Olivia Rodrigo                    drivers license
# 410        Jack Harlow, Lil Nas X  INDUSTRY BABY (feat. Jack Harlow)
# 433              Dua Lipa, DaBaby          Levitating (feat. DaBaby)
# 555        Bad Bunny, Jhay Cortez                             Dakiti
# 519                     Lil Nas X     MONTERO (Call Me By Your Name)
# 584           24kgoldn, Iann Dior             Mood (feat. Iann Dior)
#
#     released_date     streams  in_spotify_playlists  in_spotify_charts
# 84     2021-07-09  2665343922                 17050                 36
# ...

# %%
sns.barplot(y = 'track_name', x = 'streams', data = top_10_spotify, palette='pastel')
plt.title('Top 10 Most Streamed Song That Relased 2020 - 2023 in 2023 on Spotify')
# Out:
# Text(0.5, 1.0, 'Top 10 Most Streamed Song That Relased 2020 - 2023 in 2023 on Spotify')

# %% [markdown]
# Above of the table, it seems :
#  * Justin Bieber ft. The Kid Laroi, with the title track "STAY," was the most streamed and secured the first position with a total of 2,665,343,922 streams. This song was released in 2021.
#  * In the 10th position, 24kgoldn and Iann Dior's title track "Mood" had a total of 1,699,402,402 streams.
#  * The song released in 2022 by Harry Styles, titled "As It Was," secured a good position at 3rd place.
#  * The majority of the Top 10 songs were released in 2020 and 2021.

# %% [markdown]
# # Total Stream By Released_year from 2020 Untill 2023

# %%
top_song_2023.groupby(['released_year'])['streams'].sum()
# Out:
# released_year
# 2020     34703731857
# 2021     73808103039
# 2022    116402377962
# 2023     25808484104
# Name: streams, dtype: int64

# %%
sns.lineplot(data = top_song_2023, x = 'released_date', y = 'streams', hue='released_year')
# Out:
# <Axes: xlabel='released_date', ylabel='streams'>

# %% [markdown]
# Total streams by year from 2020 to 2023
# * In 2020, all streams on the Spotify Platform totaled 34,703,731,857.
# * By 2022, the number had increased to 73,808,103,039. This surge can be attributed to the impact of the COVID-19 pandemic, as people turned to streaming to alleviate boredom while staying at home.
# * The total streams further rose in 2022 to 116,402,377,962, compared to 2021. This increase suggests the release of new songs by artists in 2022.
# * However, in 2023, the total streams decreased to 25,808,484,104 from the previous year. This decline indicates that people may have resumed their pre-pandemic activities, moving away from the increased streaming habits observed during the height of the COVID-19 pandemic.demic.

# %%
top_10_spotify[['streams', 'in_spotify_playlists', 'in_spotify_charts']].corr()
# Out:
#                        streams  in_spotify_playlists  in_spotify_charts
# streams               1.000000              0.837360           0.765332
# in_spotify_playlists  0.837360              1.000000           0.873015
# in_spotify_charts     0.765332              0.873015           1.000000

# %% [markdown]
# The insights for correlations :
# * The correlation between "streams" and "in_spotify_playlists" is 0.837, indicating a strong positive correlation. This implies that songs with higher streaming numbers are likely to be included more frequently in Spotify playlists.
# * The correlation between "streams" and "in_spotify_charts" is 0.765, indicating a strong positive correlation. This implies that songs with higher streaming numbers are also likely to perform well in the overall Spotify charts.
#
# In conclusion, these factors consistently show a positive relationships, indicating that larger streaming volumes are linked to more playlist inclusions and higher Spotify chart positions.

# %%
sns.regplot(y='streams', x= 'in_spotify_charts', data = top_10_spotify)
# Out:
# <Axes: xlabel='in_spotify_charts', ylabel='streams'>

# %% [markdown]
# **Positive Trend**: \
# If the regression line has a positive slope, A positive slope for the regression line indicates a positive connection between "streams" and "in_spotify_charts." This implies that there is a tendency for the presence on Spotify charts to increase with the number of streams.

# %% [markdown]
# ## Unique Artist

# %%
unique_artist = top_song_2023['artist(s)_name'].nunique()
total_artist = top_song_2023['artist(s)_name'].count()
unique_artist_percentage = unique_artist/total_artist * 100
print('Percantage Of Unique Artist:-', unique_artist_percentage)
# Out:
# Percantage Of Unique Artist:- 68.62210095497954

# %%
unique_artist_list = np.array([unique_artist, total_artist-unique_artist])
unique_artist_labels = ["Unique_artist", "Non Unique Artist"]

# %%
explode = [0, 0.1]
palette_color = sns.color_palette('pastel') 
plt.pie(unique_artist_list, labels=unique_artist_labels, colors=palette_color, explode = explode, autopct='%.0f%%')
plt.show()

# %% [markdown]
# According to the data, 69% are original, compared to 31% who are not. This indicates that artists are more likely to be unique individuals than to be modeled after other artists in terms of form or style.
#
# There are several ways to interpret the word unique. One interpretation is that it suggests these artists are wholly unique and uninfluenced by other artists. Another interpretation is that it suggests these artists have incorporated elements from other artists into their own creations, creating something fresh and unique.

# %% [markdown]
# ## Total of Song That Are Released In 2020 - 2023

# %%
print(top_song_2023.released_year.value_counts())
ax = sns.countplot(x='released_year', data = top_song_2023, palette='pastel').set(title= " Total of Song Releases in 2020 - 2023")
# Out:
# released_year
# 2022    402
# 2023    175
# 2021    119
# 2020     37
# Name: count, dtype: int64

# %% [markdown]
# The bar graph shows:
# * the total number of song releases from 2020 to 2023. There were 37 songs released in 2020, 119 songs released in 2021, 175 songs released in 2022, and 402 songs released in 2023.
# * Overall, the number of song releases has increased each year since 2020. The biggest increase was between 2022 and 2023, with 227 more songs released in 2023.

# %% [markdown]
# ## Correlations Among Different Platform Charts

# %%
df[['in_spotify_charts', 'in_apple_charts', 'in_deezer_charts', 'in_shazam_charts']].corr()
# Out:
#                    in_spotify_charts  in_apple_charts  in_deezer_charts  \
# in_spotify_charts           1.000000         0.551985          0.600101
# in_apple_charts             0.551985         1.000000          0.383443
# in_deezer_charts            0.600101         0.383443          1.000000
# in_shazam_charts            0.569487         0.401271          0.395686
#
#                    in_shazam_charts
# in_spotify_charts          0.569487
# in_apple_charts            0.401271
# in_deezer_charts           0.395686
# in_shazam_charts           1.000000

# %% [markdown]
# The Correlation between charts in Apple, Spotify, Deezer and Shazam:
# * The correlation coefficient between Spotify and Apple Music is 0.551985. This means that there is a moderate positive correlation between the two. In other words, songs that are popular on Spotify tend to be also popular on Apple Music, and vice versa.
# * The correlation coefficient between Spotify and Deezer is 0.600101. This means that there is a slightly stronger positive correlation between Spotify and Deezer than  between Spotify and Apple Music.
# * The correlation coefficient between Spotify and Shazam is 0.569487. This means that there is a moderate positive correlation between Spotify and Shazam.
# * The correlation coefficient between Apple Music and Deezer is 0.383443. This means that there is a weak positive correlation between Apple Music and Deezer. In other words,  songs that are popular on Apple Music tend to be  popular on Deezer, but the relationship is not very strong.
# * The correlation coefficient between Apple Music and Shazam is 0.401271. This means that there is a weak positive correlation between Apple Music and Shazam.
#
# Overall, the table shows that there is a positive correlation between the number of streams a song has on all four platforms. However, the correlations are not very strong, which means that there is still a lot of variation in how popular songs are on different platforms.

# %%
sns.heatmap(df[['in_spotify_charts', 'in_apple_charts', 'in_deezer_charts', 'in_shazam_charts']].corr(), annot= True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Preperences That Makes People listen and Popular in 2020 - 2023

# %%
released_20_23[['streams', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',	'instrumentalness_%', 'liveness_%',	'speechiness_%']].corr()
# Out:
#                      streams  danceability_%  valence_%  energy_%  \
# streams             1.000000        0.005553   0.004259 -0.007499
# danceability_%      0.005553        1.000000   0.388617  0.213874
# valence_%           0.004259        0.388617   1.000000  0.370040
# energy_%           -0.007499        0.213874   0.370040  1.000000
# acousticness_%     -0.037197       -0.287134  -0.088550 -0.533335
# instrumentalness_% -0.042666       -0.042821  -0.118046 -0.020897
# liveness_%         -0.024035       -0.086956   0.026552  0.153087
# speechiness_%      -0.072524        0.138341   0.032331 -0.038527
#
#                     acousticness_%  instrumentalness_%  liveness_%  \
# streams                  -0.037197           -0.042666   -0.024035
# danceability_%           -0.287134           -0.042821   -0.086956
# valence_%                -0.088550           -0.118046    0.026552
# energy_%                 -0.533335           -0.020897    0.153087
# ...

# %%
paramaters = released_20_23[['danceability_%', 'valence_%', 'energy_%', 'acousticness_%',	'instrumentalness_%', 'liveness_%',	'speechiness_%']]

# %%
import matplotlib.pyplot as plt

# Assuming released_20_23 is your DataFrame
data = released_20_23[['danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']]

# Summing up the values in each column
sum_values = data.sum()

# Plotting a pie chart
labels = sum_values.index
plt.pie(sum_values, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Music Features')
plt.show()

# %% [markdown]
# It shows the distribution and preferences of music features. Here's a breakdown released from 2020 until 2023 :
# * Danceability: 28.3% that all song has vibe and sounds that are suitable for dance.
# * Energy: 26.6% of the song has high energy to boost the mood with the tempo and rhythm
# * Valence:21.6% of the songs are positive and happy, as indicated by the valence data. This suggests that happy and upbeat music is generally preferred.
# * acousticness: 10.9%
# * liveness:7.6%
# * speechiness:4.5%
# * instrumentalness:0.5%olume.
